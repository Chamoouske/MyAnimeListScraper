# %%
# %pip install pandas -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('AllAnimesFull.csv')
df.sample(5)
# Out:
#        position                          title      episodes  \
# 4592     4594.0    Jintian Kaishi Zuo Mingxing  ONA (13 eps)
# 122       123.0  Ansatsu Kyoushitsu 2nd Season   TV (25 eps)
# 4620     4622.0                       Kanamemo   TV (13 eps)
# 22698       NaN                     White Blue   OVA (4 eps)
# 3122     3124.0                    Idaten Jump   TV (52 eps)
#
#               release_date  members  score  \
# 4592   Dec 2019 - Mar 2020     2055   6.86
# 122    Jan 2016 - Jul 2016  1291164   8.50
# 4620   Jul 2009 - Sep 2009    37527   6.85
# 22698  Nov 2020 - Aug 2021     4419   5.53
# 3122   Oct 2005 - Sep 2006    16230   7.18
#
#                                                  details  \
# 4592   https://myanimelist.net/anime/40969/Jintian_Ka...
# 122    https://myanimelist.net/anime/30654/Ansatsu_Ky...
# 4620         https://myanimelist.net/anime/5914/Kanamemo
# 22698     https://myanimelist.net/anime/42757/White_Blue
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23070 entries, 0 to 23069
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   position      21150 non-null  float64
#  1   title         23070 non-null  object
#  2   episodes      23070 non-null  object
#  3   release_date  23070 non-null  object
#  4   members       23070 non-null  int64
#  5   score         23070 non-null  float64
#  6   details       23070 non-null  object
#  7   broadcast     7238 non-null   object
#  8   studios       23070 non-null  object
#  9   source        23070 non-null  object
#  10  genres        10609 non-null  object
#  11  themes        12543 non-null  object
#  12  demographic   9054 non-null   object
#  13  popularity    23070 non-null  int64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 2.5+ MB

# %%
df.broadcast
# Out:
# 0           ['Sundays', 'at', '17:00', '(JST)']
# 1         ['Saturdays', 'at', '00:00', '(JST)']
# 2          ['Tuesdays', 'at', '00:00', '(JST)']
# 3        ['Wednesdays', 'at', '18:00', '(JST)']
# 4        ['Wednesdays', 'at', '02:05', '(JST)']
#                           ...
# 23065                                       NaN
# 23066                                       NaN
# 23067                                       NaN
# 23068                                       NaN
# 23069                                       NaN
# Name: broadcast, Length: 23070, dtype: object

# %%
df.broadcast = df.broadcast.str.strip("[]")
df.broadcast = df.broadcast.str.replace("'", '')
df.broadcast = df.broadcast.str.replace(',', '')
df.iloc[0].broadcast
# Out:
# 'Sundays at 17:00 (JST)'

# %%
df.themes = df.themes.str.strip("[]")
df.themes = df.themes.str.replace("'", '')
df.iloc[0].themes
# Out:
# 'Military'

# %%
df.genres = df.genres.str.strip("[]")
df.genres = df.genres.str.replace("'", '')
df.iloc[0].genres
# Out:
# 'Action, Adventure, Drama, Fantasy'

# %%
df.sample(10)
# Out:
#        position                                              title  \
# 7987     7989.0                            Galactic Patrol Lensman
# 21282       NaN                                          SK∞ (OVA)
# 3441     3443.0  Rurouni Kenshin: Meiji Kenkaku Romantan - Shin...
# 12267   12271.0                                            Kremlin
# 5939     5941.0                            Saiyuuki Reload: Zeroin
# 19478   19489.0                               Jiu Hua Xiao Heshang
# 2738     2740.0                                     Robot Carnival
# 17865   17875.0                             Da Xia Shanmao He Jimi
# 22804       NaN                       Maid no Yakata: Zetsubou-hen
# 21774       NaN                Hinagiku Virgin Lost Club e Youkoso
#
#            episodes         release_date  members  score  \
# 7987    TV (25 eps)  Oct 1984 - Mar 1985     1664   6.23
# 21282   OVA (1 eps)                    -    27960   0.00
# ...

# %%
df.iloc[19478].details
# Out:
# 'https://myanimelist.net/anime/44452/Jiu_Hua_Xiao_Heshang'

# %%
df.loc[df.broadcast == 'Unknown']
# Out:
#        position                                              title  \
# 48         49.0                                    Ashita no Joe 2
# 99        100.0                                Bakuman. 3rd Season
# 102       103.0                                          Slam Dunk
# 103       104.0                                               Nana
# 112       113.0      Koukaku Kidoutai: Stand Alone Complex 2nd GIG
# ...         ...                                                ...
# 21546       NaN                 Yamada-kun to Lv999 no Koi wo Suru
# 21551       NaN                                     Youjo Senki II
# 21553       NaN  Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu ...
# 21558       NaN                                Yuru Camp△ Season 3
# 21559       NaN                                  Yuusha ga Shinda!
#
#            episodes         release_date  members  score  \
# 48      TV (47 eps)  Oct 1980 - Aug 1981    44428   8.71
# ...

# %%
df.to_csv('AllAnimesFull.csv', index=False)
